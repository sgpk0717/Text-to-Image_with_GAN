# %%
# !python3 '/content/drive/My Drive/CycleGAN_longlife/main.py' \
            --mode 'train' \
            --batch_size 4 \
            --data_dir '/content/drive/My Drive/datasets/real2water_black' \
            --ckpt_dir '/content/drive/My Drive/CycleGAN_longlife/checkpoint' \
            --log_dir '/content/drive/My Drive/CycleGAN_longlife/log' \
            --result_dir '/content/drive/My Drive/CycleGAN_longlife/result'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# TRAIN: EPOCH 0076 / 0100 | BATCH 0052 / 0202 | GEN a2b 1.1821 b2a 1.3440 | DISC a 0.5984 b 0.5602 | CYCLE a 0.1032 b 0.1202 | IDENT a 0.0946 b 0.1041 |
# TRAIN: EPOCH 0076 / 0100 | BATCH 0053 / 0202 | GEN a2b 1.1852 b2a 1.3428 | DISC a 0.5967 b 0.5606 | CYCLE a 0.1029 b 0.1196 | IDENT a 0.0942 b 0.1050 |
# TRAIN: EPOCH 0076 / 0100 | BATCH 0054 / 0202 | GEN a2b 1.1842 b2a 1.3505 | DISC a 0.5971 b 0.5580 | CYCLE a 0.1040 b 0.1192 | IDENT a 0.0954 b 0.1050 |
# TRAIN: EPOCH 0076 / 0100 | BATCH 0055 / 0202 | GEN a2b 1.1841 b2a 1.3557 | DISC a 0.5975 b 0.5584 | CYCLE a 0.1045 b 0.1193 | IDENT a 0.0959 b 0.1048 |
# TRAIN: EPOCH 0076 / 0100 | BATCH 0056 / 0202 | GEN a2b 1.1839 b2a 1.3572 | DISC a 0.5983 b 0.5620 | CYCLE a 0.1042 b 0.1188 | IDENT a 0.0954 b 0.1051 |
# TRAIN: EPOCH 0076 / 0100 | BATCH 0057 / 0202 | GEN a2b 1.1861 b2a 1.3596 | DISC a 0.5988 b 0.5617 | CYCLE a 0.1044 b 0.1196 | IDENT a 0.0953 b 0.1063 |
# ...

# %%
# !python3 '/content/drive/My Drive/CycleGAN_longlife/main.py' \
            --mode 'test' \
            --batch_size 4 \
            --data_dir '/content/drive/My Drive/datasets/real2water_black' \
            --ckpt_dir '/content/drive/My Drive/CycleGAN_longlife/checkpoint' \
            --log_dir '/content/drive/My Drive/CycleGAN_longlife/log' \
            --result_dir '/content/drive/My Drive/CycleGAN_longlife/result'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 4
# number of epoch: 100
# task: cyclegan
# opts: ['direction', array([0.])]
# network: CycleGAN
# learning type: plain
# data dir: /content/drive/My Drive/datasets/real2water_black
# ckpt dir: /content/drive/My Drive/CycleGAN_longlife/checkpoint
# log dir: /content/drive/My Drive/CycleGAN_longlife/log
# result dir: /content/drive/My Drive/CycleGAN_longlife/result
# device: cuda
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# TEST A: BATCH 0001 / 0101 |
# TEST A: BATCH 0002 / 0101 |
# TEST A: BATCH 0003 / 0101 |
# TEST A: BATCH 0004 / 0101 |
# TEST A: BATCH 0005 / 0101 |
# TEST A: BATCH 0006 / 0101 |
# TEST A: BATCH 0007 / 0101 |
# TEST A: BATCH 0008 / 0101 |
# TEST A: BATCH 0009 / 0101 |
# TEST A: BATCH 0010 / 0101 |
# TEST A: BATCH 0011 / 0101 |
# TEST A: BATCH 0012 / 0101 |
# TEST A: BATCH 0013 / 0101 |
# TEST A: BATCH 0014 / 0101 |
# ...
